# %%
import pandas as pd
import numpy as np

# %%
# PC_USB 컬럼 하위요인 표준화
# 데이터 불러오기
df = pd.read_csv("../../../00_data/01_interim/continuous.csv")

# Factor 1
df["factor1_mean"] = df[[
"p__d25060",
"p__d25058",
"p__d25057",
"p__d25056"
]].mean(axis=1)

# Factor 2
df["factor2_mean"] = df[[
"p__d25040",
"p__d25041",
"p__d25045",
"p__d25042",
"p__d25047"
]].mean(axis=1)

# Factor 3
df["factor3_mean"] = df[[
"p__d25048",
"p__d25049"
]].mean(axis=1)

# Factor 4
df["factor4_mean"] = df[[
"p__d25052",
"p__d25053"
]].mean(axis=1)

print(df[[
"p__d25060","p__d25058","p__d25057","p__d25056","factor1_mean",
"p__d25040","p__d25041","p__d25045","p__d25042","p__d25047","factor2_mean",
"p__d25048","p__d25049","factor3_mean",
"p__d25052","p__d25053","factor4_mean"
]].head())
# Out:
#    p__d25060  p__d25058  p__d25057  p__d25056  factor1_mean  p__d25040  \
# 0          1          2          2          2          1.75          3
# 1          3          5          5          5          4.50          5
# 2          5          1          4          3          3.25          4
# 3          5          5          5          5          5.00          5
# 4          4          4          4          4          4.00          5
#
#    p__d25041  p__d25045  p__d25042  p__d25047  factor2_mean  p__d25048  \
# 0          3          4          3          2           3.0          4
# 1          5          5          5          5           5.0          5
# 2          3          3          3          2           3.0          2
# 3          5          5          5          5           5.0          5
# 4          5          5          5          5           5.0          5
#
#    p__d25049  factor3_mean  p__d25052  p__d25053  factor4_mean
# ...
